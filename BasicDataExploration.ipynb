# %% [markdown]
# # Start Point: Cheking my basic skills with python with pandas df  and Kangle database
# ![Alt ou título da imagem](https://pipz.com/static/images/blog/eddie.png)

# %% [markdown]
# Temos dois tipos de entidades centrais em Pandas:
# * DataFrames
#
# O DrataFrame é como uma tabela que contem um conjunto entradas (dados), que são formatados em linhas e colunas.
# No exemplo abaixo temos um dataframe. As linhas são identificadas de forma que a primeira é sempre 0. Nas colunas ou headers, podemos especificar a natureza do dado fornecido.
#
# * Series
#
# A série é como uma lista de dados. Os dados ficam sequenciados, por ordem de "chegada", como estamos acostumados.

# %% [markdown]
# ## Exemplo de DataFrame

# %%
import pandas as pd
pd.DataFrame({'Impar':[1,3,5,7],'Par':[2,4,6,8]})
# Out:
#    Impar  Par
# 0      1    2
# 1      3    4
# 2      5    6
# 3      7    8

# %% [markdown]
# ### Exemplo de Série

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# Também temos como colocar os headers na lista
pd.Series([304, 335, 140], index=['2015 Vendas', '2016 Vendas', '2017 Vendas'], name='Produto A')
# Out:
# 2015 Vendas    304
# 2016 Vendas    335
# 2017 Vendas    140
# Name: Produto A, dtype: int64

# %% [markdown]
# ### O pandas é muito útil para importar arquivos de dados e transforma-los num DataFrame

# %%
import pandas as pd

# %%
# Salve a  filepath em uma variavel para facilitar o acesso
# melb_data.csv => Kangle  
melb_file_path = 'melb_data.csv'
# Leia o arquivo e guarde os dados em um DataFrame chamado melbourne_data 
# index_col 0, para que o Pandas utilize a primeira coluna do arquivo como a primeira coluna do DataFrame ao invés de criar uma
melbourne_data = pd.read_csv(melb_file_path, index_col=0) 
# melbourne_data = pd.read_csv(melb_file_path) 
# Exibir a tabela melbourne 
melbourne_data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
# para saber o tamanho da df 
melbourne_data.shape
#(numero de linhas (rows) , numero de colunas(columns))
# Out:
# (13580, 20)

# %%
# Para exibir as cinco primeiras linhas
melbourne_data.head()
# Out:
#                      Address  Rooms Type      Price Method SellerG       Date  \
# Suburb
# Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin  3/12/2016
# Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin  4/02/2016
# Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin  4/03/2017
# Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin  4/03/2017
# Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson  4/06/2016
#
#             Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# Suburb
# Abbotsford       2.5    3067.0       2.0       1.0  1.0     202.0
# Abbotsford       2.5    3067.0       2.0       1.0  0.0     156.0
# Abbotsford       2.5    3067.0       3.0       2.0  0.0     134.0
# Abbotsford       2.5    3067.0       3.0       2.0  1.0      94.0
# Abbotsford       2.5    3067.0       3.0       1.0  2.0     120.0
#
#             BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# ...

# %%
# sem o index_col, temos um erro no index das colunas e addrees passa a ser a segunda ao inves da primeira
# não utilizar a opcao pode acarretar erros ao utilizar metodos iloc 
mel_data_index0 = pd.read_csv("melb_data.csv")
mel_data_index0.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
# Mostrando apenas as primeiras colunas
melbourne_data.columns
# The Melbourne data has some missing values (some houses for which some variables weren't recorded.)
# Out:
# Index(['Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG', 'Date',
#        'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car', 'Landsize',
#        'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude', 'Longtitude',
#        'Regionname', 'Propertycount'],
#       dtype='object')

# %%
# dropna drops missing values (think of na as "not available")
# melbourne_data = melbourne_data.dropna(axis=0)

# %%
# What is the average lot size (rounded to nearest integer)?
avg_area_size = round(melbourne_data['Landsize'].mean())
print("A média das áreas das casas é:  ",avg_area_size , "m"+ '\u00B2')

# As of today, how old is the newest home (current year - the date in which it was built)
newest_home_age = 2025 - melbourne_data.YearBuilt.max()
print("A casa construida ha menos tempo possui ", newest_home_age, " anos.")
# Out:
# A média das áreas das casas é:   558 m²
# A casa construida ha menos tempo possui  7.0  anos.

# %%
#Some infos
Price = melbourne_data.Price

# %%
# Index Python like
melbourne_data['Price']
# melbourne_data['Price'][0]
# Out:
# Suburb
# Abbotsford       1480000.0
# Abbotsford       1035000.0
# Abbotsford       1465000.0
# Abbotsford        850000.0
# Abbotsford       1600000.0
#                    ...
# Wheelers Hill    1245000.0
# Williamstown     1031000.0
# Williamstown     1170000.0
# Williamstown     2500000.0
# Yarraville       1285000.0
# Name: Price, Length: 13580, dtype: float64

# %%
# Index in Pandas = first line of csv
melbourne_data.iloc[0]
# Out:
# Address                   85 Turner St
# Rooms                                2
# Type                                 h
# Price                        1480000.0
# Method                               S
# SellerG                         Biggin
# Date                         3/12/2016
# Distance                           2.5
# Postcode                        3067.0
# Bedroom2                           2.0
# Bathroom                           1.0
# Car                                1.0
# Landsize                         202.0
# BuildingArea                       NaN
# YearBuilt                          NaN
# CouncilArea                      Yarra
# Lattitude                     -37.7996
# Longtitude                    144.9984
# Regionname       Northern Metropolitan
# Propertycount                   4019.0
# Name: Abbotsford, dtype: object

# %%
# Apenas os preços dos imóveis com 1 quarto
OneRoomPrice = melbourne_data.query("Rooms==1")['Price'] 
OneRoomPrice
# Out:
# Suburb
# Abbotsford     300000.0
# Abbotsford     441000.0
# Abbotsford     426000.0
# Abbotsford     457000.0
# Abbotsford     470000.0
#                  ...
# Carnegie       381000.0
# Glen Huntly    600000.0
# Richmond       400000.0
# Brunswick      424000.0
# Keilor East    860000.0
# Name: Price, Length: 681, dtype: float64

# %%
#media de preço dos imoveis com 1 quarto
meanOneRoomPrice = melbourne_data.query("Rooms==1")['Price'].mean()
#round(OneRoomPrice.mean())
medianOneRoomPrice = melbourne_data.query("Rooms==1")['Price'].median()

stdOneRoomPrice = melbourne_data.query("Rooms==1")['Price'].std()

print("meanOneRoomPrice: ", meanOneRoomPrice, "medianOneRoomPrice: ", medianOneRoomPrice, "stdOneRoomPrice: ", stdOneRoomPrice)
# Out:
# meanOneRoomPrice:  433824.45080763585 medianOneRoomPrice:  385000.0 stdOneRoomPrice:  224985.70120830365

# %%
# Apenas os preços dos imóveis com 2 quarto2
TwoRoomPrice = melbourne_data.query("Rooms==2")['Price'] 
TwoRoomPrice
# Out:
# Suburb
# Abbotsford        1480000.0
# Abbotsford        1035000.0
# Abbotsford         941000.0
# Abbotsford        1636000.0
# Abbotsford        1097000.0
#                     ...
# Port Melbourne    1515000.0
# Prahran           1365000.0
# Reservoir          625500.0
# Ringwood East      937000.0
# Watsonia           650000.0
# Name: Price, Length: 3648, dtype: float64

# %%
meanTwoRoomPrice = melbourne_data.query("Rooms==2")['Price'].mean()

medianTwoRoomPrice = melbourne_data.query("Rooms==2")['Price'].median()

stdTwoRoomPrice = melbourne_data.query("Rooms==2")['Price'].std()

print("meanTwoRoomPrice: ", meanTwoRoomPrice, "medianTwoRoomPrice: ", medianTwoRoomPrice , "stdTwoRoomPrice :", stdTwoRoomPrice)
# Out:
# meanTwoRoomPrice:  775081.1894188597 medianTwoRoomPrice:  690000.0 stdTwoRoomPrice : 356125.9460610983

# %%
# boxplot with matplotlib
import matplotlib.pyplot as plt 

plt.boxplot([melbourne_data.query("Rooms==1")['Price'] , melbourne_data.query("Rooms==2")['Price']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a1a7fd0050>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a1a7fd1550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a1a7fc7710>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2a1a7fd2b90>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2a1a7fd3650>,
# ...
#  'means': []}

# %%
# boxplot with seaborn
import seaborn as sns

sns.boxplot(melbourne_data.query("Rooms in [1,2]"), x="Rooms",  y="Price", palette="Set2")
# Out:
# <Axes: xlabel='Rooms', ylabel='Price'>

# %% [markdown]
# ## Pandas indexing works in one of two paradigms. The first is index-based selection: selecting data based on its numerical position in the data. iloc follows this paradigm

# %%
# Index in Pandas = first line of csv
# On its own, the : operator, which also comes from native Python, means "everything"
melbourne_data.iloc[:, 0]
# Out:
# Suburb
# Abbotsford           85 Turner St
# Abbotsford        25 Bloomburg St
# Abbotsford           5 Charles St
# Abbotsford       40 Federation La
# Abbotsford            55a Park St
#                        ...
# Wheelers Hill        12 Strada Cr
# Williamstown        77 Merrett Dr
# Williamstown          83 Power St
# Williamstown         96 Verdon St
# Yarraville             6 Agnes St
# Name: Address, Length: 13580, dtype: object

# %%
#  When combined with other selectors, however, it can be used to indicate a range of values. 
# For example, to select the first column from just the first, second, and third row, we would do:
melbourne_data.iloc[:3, 0]
# Out:
# Suburb
# Abbotsford       85 Turner St
# Abbotsford    25 Bloomburg St
# Abbotsford       5 Charles St
# Name: Address, dtype: object

# %%
# Or, to select just the second and third entries
melbourne_data.iloc[1:3, 0]
# Out:
# Suburb
# Abbotsford    25 Bloomburg St
# Abbotsford       5 Charles St
# Name: Address, dtype: object

# %%
# as 5 ultimas linhas
melbourne_data.iloc[-5:]
# Out:
#                      Address  Rooms Type      Price Method   SellerG  \
# Suburb
# Wheelers Hill   12 Strada Cr      4    h  1245000.0      S     Barry
# Williamstown   77 Merrett Dr      3    h  1031000.0     SP  Williams
# Williamstown     83 Power St      3    h  1170000.0      S     Raine
# Williamstown    96 Verdon St      4    h  2500000.0     PI   Sweeney
# Yarraville        6 Agnes St      4    h  1285000.0     SP   Village
#
#                      Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# Suburb
# Wheelers Hill  26/08/2017      16.7    3150.0       4.0       2.0  2.0
# Williamstown   26/08/2017       6.8    3016.0       3.0       2.0  2.0
# Williamstown   26/08/2017       6.8    3016.0       3.0       2.0  4.0
# Williamstown   26/08/2017       6.8    3016.0       4.0       1.0  5.0
# Yarraville     26/08/2017       6.3    3013.0       4.0       1.0  1.0
#
#                Landsize  BuildingArea  YearBuilt CouncilArea  Lattitude  \
# Suburb
# ...

# %% [markdown]
# ## The second paradigm for attribute selection is the one followed by the loc operator: label-based selection. In this paradigm, it's the data index value, not its position, which matters

# %%
mel_data = pd.read_csv("melb_data.csv")
mel_data.head()

df = pd.DataFrame(mel_data)
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
# Local o primeiro dado da coluna de endereços
# df.loc[<linhas>, <colunas>]
df.loc[0,'Address']
# Out:
# '85 Turner St'

# %%
# Selecao das colunas de interesse
df.loc[:, ['Landsize', 'Price', 'Rooms']]
# Out:
#        Landsize      Price  Rooms
# 0         202.0  1480000.0      2
# 1         156.0  1035000.0      2
# 2         134.0  1465000.0      3
# 3          94.0   850000.0      3
# 4         120.0  1600000.0      4
# ...         ...        ...    ...
# 13575     652.0  1245000.0      4
# 13576     333.0  1031000.0      3
# 13577     436.0  1170000.0      3
# 13578     866.0  2500000.0      4
# 13579     362.0  1285000.0      4
#
# [13580 rows x 3 columns]
